# %% [markdown]
# ## import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## importing dataset

# %%
report=pd.read_csv(r"C:\Users\alasy\OneDrive\Desktop\car_sales_data.csv")
report
# Out:
#                Date      Salesperson    Customer Name   Car Make  Car Model  \
# 0        2022-08-01  Monica Moore MD      Mary Butler     Nissan     Altima
# 1        2023-03-15     Roberto Rose   Richard Pierce     Nissan      F-150
# 2        2023-04-29     Ashley Ramos     Sandra Moore       Ford      Civic
# 3        2022-09-04   Patrick Harris     Johnny Scott       Ford     Altima
# 4        2022-06-16       Eric Lopez    Vanessa Jones      Honda  Silverado
# ...             ...              ...              ...        ...        ...
# 2499995  2022-05-26   Isabella Moore      Shirley Lee  Chevrolet  Silverado
# 2499996  2022-10-03    Kimberly Snow     Tara Rodgers       Ford      F-150
# 2499997  2022-06-07    Jessica Young   Jennifer Moore  Chevrolet      Civic
# 2499998  2023-02-15    Donald Barber      Ashley Diaz      Honda  Silverado
# 2499999  2023-03-24     Kayla Fowler  Nathan Thompson      Honda      Civic
#
# ...

# %% [markdown]
# ## univariate analysis

# %%
report.dtypes
# Out:
# Date                  object
# Salesperson           object
# Customer Name         object
# Car Make              object
# Car Model             object
# Car Year               int64
# Sale Price             int64
# Commission Rate      float64
# Commission Earned    float64
# dtype: object

# %%
report["Car Year"].plot.hist(color="pink")
plt.title("histogram of car sales")
plt.xlabel("sale year")
plt.ylabel("freq/count")
plt.show()

# %%
plt.hist(report["Commission Rate"],color="cyan")
plt.xlabel("Commission Rate")
plt.ylabel("frequency")
plt.title("histogram of Commission Rate ")
plt.show()

# %%
sns.distplot(report["Commission Earned"],color="red",kde=True)
plt.xlabel("Commission Earned")
plt.ylabel("count")
plt.title("histogram of Commission Earned")
plt.show()
# Out:
# C:\Users\alasy\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(report["Sale Price"])
plt.show()
# Out:
# C:\Users\alasy\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(report["Sale Price"],color="blue")
# Out:
# C:\Users\alasy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sale Price'>

# %%
report["Commission Rate"].plot.box(vert=False)
plt.show()

# %%
report["Car Make"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
sns.countplot(report["Car Year"])
plt.legend()
# Out:
# C:\Users\alasy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
report["Car Year"].value_counts().plot.bar(color=["violet","indigo","blue","green","yellow","orange"])
plt.legend()

# %%
report["Car Model"].value_counts().plot.line(color="violet")
# Out:
# <AxesSubplot:>

# %%
report["Car Year"].value_counts().plot.pie(autopct="%0.2f")
plt.legend()
plt.show()

# %% [markdown]
# ## Bivariate analysis

# %%
plt.scatter(report["Commission Rate"],report["Commission Earned"],c="indigo")
plt.xlabel("Commission rate")
plt.ylabel("Commission Earned")
plt.show()

# %%
sns.pairplot(report)
