# %% [markdown]
# ## import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## import dataset

# %%
file=pd.read_csv(r"C:\Users\alasy\Downloads\loandata.csv")
file
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# ## univariate analysis

# %%
## ccontinuous dataset
file.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
file["LoanAmount"].plot.hist(color="pink")
plt.title("histogram of loan amount")
plt.xlabel("Loan")
plt.ylabel("freq/count")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1505         try:
# -> 1506             ret = self.converter.convert(x, self.units, self)
#    1507         except Exception as e:
#
# ~\anaconda3\lib\site-packages\matplotlib\category.py in convert(value, unit, axis)
#      48         if unit is None:
# ---> 49             raise ValueError(
#      50                 'Missing category information for StrCategoryConverter; '
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6920\3703084435.py in <module>
# ...

# %%
file["ApplicantIncome"].plot.hist(color="black")
plt.title("histogram of Applicant income")
plt.xlabel("income")
plt.ylabel("freq/count")
plt.show()

# %%
plt.hist(file["CoapplicantIncome"],color="cyan")
plt.xlabel("coapplicant income")
plt.ylabel("count")
plt.title("histogram of coapplicant income")
plt.show()

# %%
sns.displot(file["CoapplicantIncome"],color="red",kde=True)
plt.xlabel("coapplicant income")
plt.ylabel("count")
plt.title("histogram of coapplicant income")
plt.show()

# %%
file["CoapplicantIncome"].plot.density(color="blue")
plt.xlabel("coapplicant income")
plt.ylabel("count")
plt.title("histogram of coapplicant income")
plt.show()

# %%
sns.displot(file["CoapplicantIncome"],color="red",kde=True)
plt.show()

# %%
sns.distplot(file["CoapplicantIncome"])
plt.show()
# Out:
# C:\Users\alasy\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import scipy as sp

# %% [markdown]
# ## box plot

# %%
sns.boxplot(file["LoanAmount"],color="blue")
# Out:
# C:\Users\alasy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LoanAmount'>

# %%
file["ApplicantIncome"].plot.box(vert=False)
plt.show()

# %%
plt.boxplot(file["ApplicantIncome"])
plt.show()

# %% [markdown]
# ## discrete

# %%
file["Gender"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
file["Married"].value_counts().plot.bar()
plt.show()

# %% [markdown]
# ## count plot

# %%
sns.countplot(file["Dependents"])
plt.legend()
# Out:
# C:\Users\alasy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
cars=pd.read_csv(r"C:\Users\alasy\Downloads\CARS_1.csv")
cars
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
cars["Make"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
cars["Type"].value_counts().plot.bar(color=["violet","indigo","blue","green","yellow","orange"])
plt.legend()

# %%
cars["Type"].value_counts().plot.line(color="violet")
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x="Make",data=cars)
# Out:
# <AxesSubplot:xlabel='Make', ylabel='count'>

# %%
cars["Type"].value_counts().plot.pie(autopct="%0.2f")
plt.legend()
plt.show()

# %%
cars["Origin"].value_counts().plot.pie(autopct="%0.2f")
plt.legend()
plt.show()

# %%
cars[["Wheelbase","EngineSize","Invoice"]].plot.hist(color=["yellow","black","red"])
plt.show()

# %%
cars["Length"].plot(kind="bar",color="red")
plt.show()

# %%
cars["Type"].value_counts().plot.pie(autopct="%0.2f")
plt.legend()
plt.show()

# %%
cars["MSRP"].value_counts().plot.line(color="violet")
plt.show()

# %%
cars["Horsepower"].plot.box(color="orange")
plt.show()

# %%
cars[["Horsepower","Cylinders"]].plot(kind="area",color=["violet","black"])
plt.show()

# %%
dir(cars.plot)
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accessors',
#  '_all_kinds',
#  '_common_kinds',
#  '_constructor',
#  '_dataframe_kinds',
#  '_dir_additions',
#  '_dir_deletions',
#  '_get_call_args',
#  '_hidden_attrs',
#  '_kind_aliases',
#  '_parent',
#  '_reset_cache',
#  '_series_kinds',
#  'area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %% [markdown]
# ## Bivariate analysis

# %%
plt.scatter(file["LoanAmount"],file["ApplicantIncome"],c="indigo")
plt.xlabel("LoanAMount")
plt.ylabel("ApplicantIncome")
plt.show()

# %%
file[["ApplicantIncome","LoanAmount"]].corr()
# Out:
#                  ApplicantIncome  LoanAmount
# ApplicantIncome         1.000000    0.570909
# LoanAmount              0.570909    1.000000

# %%
plt.scatter(file["CoapplicantIncome"],file["LoanAmount"],c="red")

# %%
file[["CoapplicantIncome","LoanAmount"]].corr()
# Out:
#                    CoapplicantIncome  LoanAmount
# CoapplicantIncome           1.000000    0.188619
# LoanAmount                  0.188619    1.000000

# %%
sns.pairplot(file)

# %%
sns.heatmap(file[["ApplicantIncome","CoapplicantIncome","LoanAmount",]])
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(file.corr(),cmap="copper",annot=True)
plt.show()

# %%
file.corr()
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# Credit_History           -0.014715          -0.002056   -0.008433
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.045306       -0.014715
# CoapplicantIncome         -0.059878       -0.002056
# LoanAmount                 0.039447       -0.008433
# Loan_Amount_Term           1.000000        0.001470
# Credit_History             0.001470        1.000000

# %%
plt.subplot(233)    #subplot(row,column,position)
file["LoanAmount"].plot(kind="hist",color="red")
plt.subplot(231)
file["ApplicantIncome"].plot(kind="kde",color="blue")
plt.subplot(232)
file["CoapplicantIncome"].plot(kind="area",color="black")
plt.subplot(234)
file["LoanAmount"].plot(kind="box",color="orange")
# Out:
# <AxesSubplot:>
