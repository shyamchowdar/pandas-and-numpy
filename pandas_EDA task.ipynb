# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\alasy\Downloads\Iris.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
##  showing data using bar graph with pandas
data["SepalLengthCm"].plot.bar(color="blue")
plt.title("bar on sepal length")
plt.xlabel("sepal length")
plt.ylabel("cm")
plt.show()

# %%
##showing data using histogram 
data["PetalLengthCm"].plot.hist(color="orange")
plt.title("histogram on petal length")
plt.xlabel("petal length")
plt.ylabel("cm")
plt.show()

# %%
## showing data using pie chart with matplotlib
plt.pie(data["SepalWidthCm"])
plt.title("pie on sepal width")
plt.xlabel("sepal width")
plt.ylabel("cm")
plt.show()

# %%
## showing data using histogram with using seaborn 
sns.displot(data["PetalWidthCm"],color="black")
plt.title("Petalwidth")
plt.xlabel("Petalwidth")
plt.ylabel("cm")
plt.show()

# %%
## box plot
data["SepalLengthCm"].plot.box(vert=False)
# Out:
# C:\Users\alasy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Id'>

# %%
data["SepalLengthCm"].plot.box(vert=False)
# Out:
# <AxesSubplot:>

# %%
data["PetalLengthCm"].plot.box(vert=False)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data["SepalWidthCm"],color="black")
# Out:
# C:\Users\alasy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SepalWidthCm'>

# %%
##  finding discrete values
data["Species"].value_counts().plot.bar(color=["RED","blue","black"])
plt.show()

# %%
## count plot:
sns.countplot(data["Species"])
plt.legend()
# Out:
# C:\Users\alasy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
